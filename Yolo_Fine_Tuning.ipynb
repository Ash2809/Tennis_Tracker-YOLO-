# %% [markdown]
# <a href="https://colab.research.google.com/github/Ash2809/Tennis_Tracker-YOLO-/blob/main/Yolo_Fine_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="fQMpBhjlpeBGgOuZcyPZ")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov8:: 100%|██████████| 1168/1168 [00:00<00:00, 3639.39it/s]

# %%
import shutil

# %%
shutil.move(r"/content/tennis-ball-detection-6/train",
            "/content/tennis-ball-detection-6/tennis-ball-detection-6/train")

shutil.move(r"/content/tennis-ball-detection-6/test",
            "/content/tennis-ball-detection-6/tennis-ball-detection-6/test")

shutil.move(r"/content/tennis-ball-detection-6/valid",
            "/content/tennis-ball-detection-6/tennis-ball-detection-6/valid" )
# Out:
# '/content/tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8l.pt")
# Out:
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 121MB/s]

# %%
# !yolo task = detect mode = train model = yolov8l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
